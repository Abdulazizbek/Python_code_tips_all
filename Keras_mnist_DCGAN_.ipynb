# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulazizbek/Python_code_tips_all/blob/master/Keras_mnist_DCGAN_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
discriminator = keras.Sequential([
                                  keras.Input(shape=(28, 28, 1)),
                                  layers.Conv2D(64, (3, 3), strides=(2, 2), padding='same'),
                                  layers.LeakyReLU(alpha=0.2),
                                  layers.Conv2D(128, (3, 3), strides=(2, 2), padding='same'),
                                  layers.LeakyReLU(alpha=0.2),
                                  layers.GlobalMaxPooling2D(),
                                  layers.Dense(1)
                                  ], name='Discriminator')

# %%
discriminator.summary()
# Out:
# Model: "Discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 14, 14, 64)        640
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 128)         73856
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 7, 7, 128)         0
# _________________________________________________________________
# global_max_pooling2d_1 (Glob (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 74,625
# Trainable params: 74,625
# Non-trainable params: 0
# _________________________________________________________________

# %%
latent_dim = 128

generator = keras.Sequential([
                              keras.Input(shape=(latent_dim, )),
                              layers.Dense(7 * 7 * 128),
                              layers.LeakyReLU(alpha=0.2),
                              layers.Reshape((7, 7, 128)),
                              layers.Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same'),
                              layers.LeakyReLU(alpha=0.2),
                              layers.Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same'),
                              layers.LeakyReLU(alpha=0.2),
                              layers.Conv2D(1, (7, 7), padding='same', activation='sigmoid')
], name='Generator')

# %%
generator.summary()
# Out:
# Model: "Generator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 6272)              809088
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 6272)              0
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 28, 28, 128)       262272
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 1)         6273
# =================================================================
# Total params: 1,339,905
# Trainable params: 1,339,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
d_optimizer = keras.optimizers.Adam(learning_rate=0.0003)
g_optimizer = keras.optimizers.Adam(learning_rate=0.0004)

#loss function
loss_fn = keras.losses.BinaryCrossentropy(from_logits=True)

# %%
@tf.function
def train_step(real_images):
  # Sample random points in the latent space
  random_latent_vectors = tf.random.normal(shape=(batch_size, latent_dim))

  # decode them to fake images
  generated_images = generator(random_latent_vectors)

  # Combine them with real images
  combined_images = tf.concat([generated_images, real_images], axis=0)
  
  # Assemble  labels discriminating real from fake images
  labels = tf.concat([tf.ones((batch_size, 1)),
                      tf.zeros((real_images.shape[0], 1))], axis=0)
  
  # Add random noise to the labels - important trick
  labels += 0.05 * tf.random.uniform(labels.shape)

  # Train the discriminator
  with tf.GradientTape() as tape:
    predictions = discriminator(combined_images)
    d_loss = loss_fn(labels, predictions)

  grads = tape.gradient(d_loss, discriminator.trainable_weights)
  d_optimizer.apply_gradients(zip(grads, discriminator.trainable_weights))

  # Sample random points in the latent space
  random_latent_vectors = tf.random.normal(shape=(batch_size, latent_dim))

  #Assemble labels that say "all real images"
  misleading_labels = tf.zeros(batch_size, 1)

  # Train the generator (we are not updating weights of discriminator)
  with tf.GradientTape() as tape:
    predictions = discriminator(generator(random_latent_vectors))
    g_loss = loss_fn(misleading_labels, predictions)
  grads = tape.gradient(g_loss, generator.trainable_weights)
  g_optimizer.apply_gradients(zip(grads, generator.trainable_weights))
  return d_loss, g_loss, generated_images

# %%
# Prepare the dataset. We are using both training and test MNIST digits
batch_size = 64
(x_train, _), (x_test, _) = keras.datasets.mnist.load_data()
all_digits = np.concatenate([x_train, x_test])
all_digits = all_digits.astype('float32') / 255.
all_digits = np.reshape(all_digits, (-1, 28, 28, 1))

dataset = tf.data.Dataset.from_tensor_slices(all_digits)
dataset = dataset.shuffle(buffer_size=1024).batch(batch_size)

# %%
epochs = 100
save_dir = './'

for epoch in range(epochs):
  print('\n Start epoch', epoch)

  for step, real_images in enumerate(dataset):
    # Train the discriminator & generator on one batch of real images
    d_loss, g_loss, generated_images = train_step(real_images)

    # Occasionaly save / plot
    if step % 200 == 0:
      print('discriminator loss at step %d: %.4f' % (step, d_loss))
      print('generator loss at step %d: %.4f' % (step, g_loss))

      # Save one generated image
      img = tf.keras.preprocessing.image.array_to_img(
          generated_images[0] * 255., scale=False)
      img.save(os.path.join(save_dir, 'generated_img' + str(step) + '.png'))
# Out:
#  Start epoch 0
# discriminator loss at step 0: 0.7159
# generator loss at step 0: 0.7522
# discriminator loss at step 200: 0.5561
# generator loss at step 200: 1.1286
# discriminator loss at step 400: 0.5207
# generator loss at step 400: 1.4344
# discriminator loss at step 600: 0.5691
# generator loss at step 600: 1.5948
# discriminator loss at step 800: 0.5590
# generator loss at step 800: 1.3196
# discriminator loss at step 1000: 0.2967
# generator loss at step 1000: 1.8278
#
#  Start epoch 1
# discriminator loss at step 0: 0.2634
# generator loss at step 0: 2.1113
# discriminator loss at step 200: 0.2040
# generator loss at step 200: 2.3185
# discriminator loss at step 400: 0.1500
# generator loss at step 400: 3.2303
# discriminator loss at step 600: 0.1795
# generator loss at step 600: 3.0537
# discriminator loss at step 800: 0.1007
# generator loss at step 800: 2.9257
# discriminator loss at step 1000: 0.1062
# generator loss at step 1000: 3.1215
#
#  Start epoch 2
# discriminator loss at step 0: 0.0936
# generator loss at step 0: 4.0690
# discriminator loss at step 200: 0.1278
# generator loss at step 200: 3.3166
# discriminator loss at step 400: 0.0823
# generator loss at step 400: 4.2063
# discriminator loss at step 600: 0.4878
# generator loss at step 600: 1.6776
# discriminator loss at step 800: 0.5648
# generator loss at step 800: 1.1949
# discriminator loss at step 1000: 0.5945
# generator loss at step 1000: 0.8562
#
#  Start epoch 3
# discriminator loss at step 0: 0.5483
# generator loss at step 0: 1.2343
# discriminator loss at step 200: 0.6388
# generator loss at step 200: 0.8028
# discriminator loss at step 400: 0.7304
# generator loss at step 400: 0.7451
# discriminator loss at step 600: 0.4644
# generator loss at step 600: 1.0231
# discriminator loss at step 800: 0.6248
# generator loss at step 800: 1.1602
# discriminator loss at step 1000: 0.5914
# generator loss at step 1000: 0.9746
#
#  Start epoch 4
# discriminator loss at step 0: 0.5843
# generator loss at step 0: 1.0761
# discriminator loss at step 200: 0.6821
# generator loss at step 200: 0.9362
# discriminator loss at step 400: 0.6641
# generator loss at step 400: 0.9092
# discriminator loss at step 600: 0.6232
# generator loss at step 600: 0.8479
# discriminator loss at step 800: 0.6698
# generator loss at step 800: 1.1199
# discriminator loss at step 1000: 0.4851
# generator loss at step 1000: 1.2121
#
#  Start epoch 5
# discriminator loss at step 0: 0.5354
# generator loss at step 0: 1.1797
# discriminator loss at step 200: 0.5875
# generator loss at step 200: 0.9342
# discriminator loss at step 400: 0.5065
# generator loss at step 400: 1.2492
# discriminator loss at step 600: 0.7471
# generator loss at step 600: 0.7290
# discriminator loss at step 800: 0.5753
# generator loss at step 800: 0.8567
# discriminator loss at step 1000: 0.6489
# generator loss at step 1000: 0.9307
#
#  Start epoch 6
# discriminator loss at step 0: 0.5857
# generator loss at step 0: 1.0020
# discriminator loss at step 200: 0.6483
# generator loss at step 200: 0.8953
# discriminator loss at step 400: 0.5966
# generator loss at step 400: 0.9817
# discriminator loss at step 600: 0.5274
# generator loss at step 600: 1.2482
# discriminator loss at step 800: 0.5799
# generator loss at step 800: 1.0238
# discriminator loss at step 1000: 0.5957
# generator loss at step 1000: 1.0575
#
#  Start epoch 7
# discriminator loss at step 0: 0.5686
# generator loss at step 0: 1.1334
# discriminator loss at step 200: 0.5899
# generator loss at step 200: 0.8914
# discriminator loss at step 400: 0.6745
# generator loss at step 400: 0.9470
# discriminator loss at step 600: 0.5925
# generator loss at step 600: 0.8608
# discriminator loss at step 800: 0.3944
# generator loss at step 800: 1.4291
# discriminator loss at step 1000: 0.5807
# generator loss at step 1000: 0.9377
#
#  Start epoch 8
# discriminator loss at step 0: 0.6148
# generator loss at step 0: 1.0682
# discriminator loss at step 200: 0.6269
# generator loss at step 200: 0.8820
# discriminator loss at step 400: 0.5655
# generator loss at step 400: 1.0083
# discriminator loss at step 600: 0.5772
# generator loss at step 600: 1.0665
# discriminator loss at step 800: 0.6112
# generator loss at step 800: 1.0614
# discriminator loss at step 1000: 0.5863
# generator loss at step 1000: 1.0415
#
#  Start epoch 9
# discriminator loss at step 0: 0.6107
# generator loss at step 0: 1.1888
# discriminator loss at step 200: 0.5416
# generator loss at step 200: 0.9625
# discriminator loss at step 400: 0.6118
# generator loss at step 400: 0.9848
# discriminator loss at step 600: 0.4925
# generator loss at step 600: 1.0082
# discriminator loss at step 800: 0.6180
# generator loss at step 800: 0.8312
# discriminator loss at step 1000: 0.6019
# generator loss at step 1000: 0.9672
#
#  Start epoch 10
# discriminator loss at step 0: 0.6966
# generator loss at step 0: 1.0312
# discriminator loss at step 200: 0.6480
# generator loss at step 200: 1.0955
# discriminator loss at step 400: 0.6891
# generator loss at step 400: 0.9362
# discriminator loss at step 600: 0.5778
# generator loss at step 600: 1.0178
# discriminator loss at step 800: 0.6380
# generator loss at step 800: 0.7763
# discriminator loss at step 1000: 0.5839
# generator loss at step 1000: 1.1282
#
#  Start epoch 11
# discriminator loss at step 0: 0.5988
# generator loss at step 0: 1.1866
# discriminator loss at step 200: 0.5650
# generator loss at step 200: 1.0099
# discriminator loss at step 400: 0.5396
# generator loss at step 400: 1.2132
# discriminator loss at step 600: 0.6048
# generator loss at step 600: 1.0129
# discriminator loss at step 800: 0.5606
# generator loss at step 800: 1.2716
# discriminator loss at step 1000: 0.5750
# generator loss at step 1000: 0.9137
#
#  Start epoch 12
# discriminator loss at step 0: 0.5499
# generator loss at step 0: 1.1837
# discriminator loss at step 200: 0.4596
# generator loss at step 200: 1.3011
# discriminator loss at step 400: 0.5819
# generator loss at step 400: 0.8511
# discriminator loss at step 600: 0.5880
# generator loss at step 600: 0.9876
# discriminator loss at step 800: 0.5495
# generator loss at step 800: 1.0836
# discriminator loss at step 1000: 0.6262
# generator loss at step 1000: 1.1040
#
#  Start epoch 13
# discriminator loss at step 0: 0.5410
# generator loss at step 0: 1.0756
# discriminator loss at step 200: 0.6471
# generator loss at step 200: 0.9566
# discriminator loss at step 400: 0.5574
# generator loss at step 400: 1.0865
# discriminator loss at step 600: 0.5800
# generator loss at step 600: 1.0121
# discriminator loss at step 800: 0.5659
# generator loss at step 800: 1.0927
# discriminator loss at step 1000: 0.5967
# generator loss at step 1000: 0.9018
#
#  Start epoch 14
# discriminator loss at step 0: 0.6276
# generator loss at step 0: 1.2402
# discriminator loss at step 200: 0.5750
# generator loss at step 200: 0.9674
# discriminator loss at step 400: 0.6059
# generator loss at step 400: 1.0794
# discriminator loss at step 600: 0.5386
# generator loss at step 600: 1.0283
# discriminator loss at step 800: 0.6043
# generator loss at step 800: 1.0487
# discriminator loss at step 1000: 0.5336
# generator loss at step 1000: 1.0777
#
#  Start epoch 15
# discriminator loss at step 0: 0.6102
# generator loss at step 0: 1.1042
# discriminator loss at step 200: 0.5544
# generator loss at step 200: 1.0449
# discriminator loss at step 400: 0.6148
# generator loss at step 400: 0.8539
# discriminator loss at step 600: 0.6297
# generator loss at step 600: 0.9157
# discriminator loss at step 800: 0.6224
# generator loss at step 800: 0.9211
# discriminator loss at step 1000: 0.6000
# generator loss at step 1000: 1.0102
#
#  Start epoch 16
# discriminator loss at step 0: 0.6228
# generator loss at step 0: 1.1785
# discriminator loss at step 200: 0.6091
# generator loss at step 200: 0.9322
# discriminator loss at step 400: 0.5901
# generator loss at step 400: 0.8339
# discriminator loss at step 600: 0.5784
# generator loss at step 600: 1.1464
# discriminator loss at step 800: 0.5765
# generator loss at step 800: 1.0921
# discriminator loss at step 1000: 0.5857
# generator loss at step 1000: 1.0507
#
#  Start epoch 17
# discriminator loss at step 0: 0.5801
# generator loss at step 0: 1.1645
# discriminator loss at step 200: 0.6293
# generator loss at step 200: 0.8578
# discriminator loss at step 400: 0.5872
# generator loss at step 400: 0.9572
# discriminator loss at step 600: 0.6044
# generator loss at step 600: 1.0415
# discriminator loss at step 800: 0.6219
# generator loss at step 800: 0.9205
# discriminator loss at step 1000: 0.6089
# generator loss at step 1000: 1.1611
#
#  Start epoch 18
# discriminator loss at step 0: 0.6031
# generator loss at step 0: 1.1875
# discriminator loss at step 200: 0.6330
# generator loss at step 200: 0.9722
# discriminator loss at step 400: 0.6410
# generator loss at step 400: 0.8850
# discriminator loss at step 600: 0.6087
# generator loss at step 600: 1.1430
# discriminator loss at step 800: 0.6326
# generator loss at step 800: 1.0798
# discriminator loss at step 1000: 0.6709
# generator loss at step 1000: 1.0187
#
#  Start epoch 19
# discriminator loss at step 0: 0.5852
# generator loss at step 0: 1.2630
# discriminator loss at step 200: 0.6215
# generator loss at step 200: 1.0519
# discriminator loss at step 400: 0.6073
# generator loss at step 400: 1.0281
# discriminator loss at step 600: 0.6500
# generator loss at step 600: 0.9722
# discriminator loss at step 800: 0.5645
# generator loss at step 800: 1.0523
# discriminator loss at step 1000: 0.5998
# generator loss at step 1000: 0.9889
#
#  Start epoch 20
# discriminator loss at step 0: 0.6193
# generator loss at step 0: 1.2838
# discriminator loss at step 200: 0.5881
# generator loss at step 200: 0.9719
# discriminator loss at step 400: 0.6116
# generator loss at step 400: 0.8868
# discriminator loss at step 600: 0.6044
# generator loss at step 600: 1.0965
# discriminator loss at step 800: 0.6072
# generator loss at step 800: 0.9303
# discriminator loss at step 1000: 0.6259
# generator loss at step 1000: 0.7446
#
#  Start epoch 21
# discriminator loss at step 0: 0.5695
# generator loss at step 0: 1.2082
# discriminator loss at step 200: 0.5933
# generator loss at step 200: 1.0356
# discriminator loss at step 400: 0.5968
# generator loss at step 400: 1.0327
# discriminator loss at step 600: 0.6276
# generator loss at step 600: 1.0169
# discriminator loss at step 800: 0.6270
# generator loss at step 800: 0.9921
# discriminator loss at step 1000: 0.6431
# generator loss at step 1000: 0.9713
#
#  Start epoch 22
# discriminator loss at step 0: 0.6154
# generator loss at step 0: 1.0612
# discriminator loss at step 200: 0.6687
# generator loss at step 200: 0.9697
# discriminator loss at step 400: 0.6272
# generator loss at step 400: 1.1508
# discriminator loss at step 600: 0.6232
# generator loss at step 600: 0.8846
# discriminator loss at step 800: 0.6168
# generator loss at step 800: 1.0645
# discriminator loss at step 1000: 0.5795
# generator loss at step 1000: 1.0223
#
#  Start epoch 23
# discriminator loss at step 0: 0.5976
# generator loss at step 0: 1.3488
# discriminator loss at step 200: 0.6696
# generator loss at step 200: 0.9093
# discriminator loss at step 400: 0.6465
# generator loss at step 400: 0.9062
# discriminator loss at step 600: 0.6211
# generator loss at step 600: 0.8083
# discriminator loss at step 800: 0.6292
# generator loss at step 800: 0.9281
# discriminator loss at step 1000: 0.5911
# generator loss at step 1000: 1.0325
#
#  Start epoch 24
# discriminator loss at step 0: 0.6433
# generator loss at step 0: 1.0840
# discriminator loss at step 200: 0.6158
# generator loss at step 200: 0.8859
# discriminator loss at step 400: 0.6193
# generator loss at step 400: 0.9377
# discriminator loss at step 600: 0.6026
# generator loss at step 600: 0.9245
# discriminator loss at step 800: 0.6551
# generator loss at step 800: 0.9527
# discriminator loss at step 1000: 0.6410
# generator loss at step 1000: 0.8817
#
#  Start epoch 25
# discriminator loss at step 0: 0.5972
# generator loss at step 0: 1.1035
# discriminator loss at step 200: 0.6033
# generator loss at step 200: 0.9023
# discriminator loss at step 400: 0.6973
# generator loss at step 400: 0.9364
# discriminator loss at step 600: 0.6274
# generator loss at step 600: 1.0135
# discriminator loss at step 800: 0.6020
# generator loss at step 800: 1.0799
# discriminator loss at step 1000: 0.6640
# generator loss at step 1000: 0.9271
#
#  Start epoch 26
# discriminator loss at step 0: 0.6025
# generator loss at step 0: 1.1923
# discriminator loss at step 200: 0.6019
# generator loss at step 200: 1.0743
# discriminator loss at step 400: 0.6932
# generator loss at step 400: 0.9194
# discriminator loss at step 600: 0.6128
# generator loss at step 600: 0.8015
# discriminator loss at step 800: 0.6591
# generator loss at step 800: 1.0798
# discriminator loss at step 1000: 0.6741
# generator loss at step 1000: 1.0172
#
#  Start epoch 27
# discriminator loss at step 0: 0.6622
# generator loss at step 0: 1.1338
# discriminator loss at step 200: 0.6608
# generator loss at step 200: 0.9509
# discriminator loss at step 400: 0.6268
# generator loss at step 400: 0.9208
# discriminator loss at step 600: 0.6304
# generator loss at step 600: 0.9740
# discriminator loss at step 800: 0.6104
# generator loss at step 800: 0.9104
# discriminator loss at step 1000: 0.6404
# generator loss at step 1000: 0.8680
#
#  Start epoch 28
# discriminator loss at step 0: 0.6271
# generator loss at step 0: 1.2426
# discriminator loss at step 200: 0.6721
# generator loss at step 200: 0.8275
# discriminator loss at step 400: 0.6512
# generator loss at step 400: 0.9475
# discriminator loss at step 600: 0.6532
# generator loss at step 600: 0.8741
# discriminator loss at step 800: 0.6812
# generator loss at step 800: 0.8890
# discriminator loss at step 1000: 0.6322
# generator loss at step 1000: 1.0877
#
#  Start epoch 29
# discriminator loss at step 0: 0.6397
# generator loss at step 0: 1.0208
# discriminator loss at step 200: 0.6671
# generator loss at step 200: 0.8223
# discriminator loss at step 400: 0.6052
# generator loss at step 400: 0.9978
# discriminator loss at step 600: 0.6534
# generator loss at step 600: 0.7599
# discriminator loss at step 800: 0.5915
# generator loss at step 800: 0.8686
# discriminator loss at step 1000: 0.6317
# generator loss at step 1000: 0.8815
#
#  Start epoch 30
# discriminator loss at step 0: 0.6517
# generator loss at step 0: 1.2255
# discriminator loss at step 200: 0.6226
# generator loss at step 200: 0.7732
# discriminator loss at step 400: 0.6863
# generator loss at step 400: 0.8511
# discriminator loss at step 600: 0.6457
# generator loss at step 600: 0.9605
# discriminator loss at step 800: 0.5937
# generator loss at step 800: 0.9545
# discriminator loss at step 1000: 0.6133
# generator loss at step 1000: 1.0485
#
#  Start epoch 31
# discriminator loss at step 0: 0.6255
# generator loss at step 0: 1.2345
# discriminator loss at step 200: 0.6454
# generator loss at step 200: 0.7754
# discriminator loss at step 400: 0.6402
# generator loss at step 400: 0.9384
# discriminator loss at step 600: 0.6688
# generator loss at step 600: 0.8513
# discriminator loss at step 800: 0.6188
# generator loss at step 800: 0.8932
# discriminator loss at step 1000: 0.6680
# generator loss at step 1000: 0.9327
#
#  Start epoch 32
# discriminator loss at step 0: 0.6787
# generator loss at step 0: 1.0837
# discriminator loss at step 200: 0.6376
# generator loss at step 200: 0.8548
# discriminator loss at step 400: 0.6827
# generator loss at step 400: 0.8896
# discriminator loss at step 600: 0.5790
# generator loss at step 600: 0.8746
# discriminator loss at step 800: 0.6012
# generator loss at step 800: 0.9701
# discriminator loss at step 1000: 0.6081
# generator loss at step 1000: 0.8587
#
#  Start epoch 33
# discriminator loss at step 0: 0.5698
# generator loss at step 0: 1.1032
# discriminator loss at step 200: 0.6207
# generator loss at step 200: 0.8639
# discriminator loss at step 400: 0.6725
# generator loss at step 400: 0.8735
# discriminator loss at step 600: 0.6066
# generator loss at step 600: 0.8027
# discriminator loss at step 800: 0.6523
# generator loss at step 800: 1.0842
# discriminator loss at step 1000: 0.6769
# generator loss at step 1000: 0.8722
#
#  Start epoch 34
# discriminator loss at step 0: 0.6220
# generator loss at step 0: 1.0170
# discriminator loss at step 200: 0.6210
# generator loss at step 200: 1.0866
# discriminator loss at step 400: 0.6463
# generator loss at step 400: 0.8716
# discriminator loss at step 600: 0.6278
# generator loss at step 600: 0.8830
# discriminator loss at step 800: 0.6517
# generator loss at step 800: 0.9596
# discriminator loss at step 1000: 0.6115
# generator loss at step 1000: 0.8054
#
#  Start epoch 35
# discriminator loss at step 0: 0.6270
# generator loss at step 0: 1.2143
# discriminator loss at step 200: 0.6221
# generator loss at step 200: 0.9725
# discriminator loss at step 400: 0.6681
# generator loss at step 400: 0.8847
# discriminator loss at step 600: 0.6478
# generator loss at step 600: 1.0262
# discriminator loss at step 800: 0.6320
# generator loss at step 800: 1.0827
# discriminator loss at step 1000: 0.6402
# generator loss at step 1000: 1.0130
#
#  Start epoch 36
# discriminator loss at step 0: 0.6192
# generator loss at step 0: 1.0946
# discriminator loss at step 200: 0.6197
# generator loss at step 200: 0.9344
# discriminator loss at step 400: 0.6179
# generator loss at step 400: 0.8148
# discriminator loss at step 600: 0.6434
# generator loss at step 600: 0.8778
# discriminator loss at step 800: 0.6690
# generator loss at step 800: 0.7296
# discriminator loss at step 1000: 0.6555
# generator loss at step 1000: 0.9096
#
#  Start epoch 37
# discriminator loss at step 0: 0.6404
# generator loss at step 0: 1.2164
# discriminator loss at step 200: 0.6257
# generator loss at step 200: 1.0129
# discriminator loss at step 400: 0.6407
# generator loss at step 400: 0.8473
# discriminator loss at step 600: 0.6130
# generator loss at step 600: 0.9837
# discriminator loss at step 800: 0.6323
# generator loss at step 800: 1.0530
# discriminator loss at step 1000: 0.6291
# generator loss at step 1000: 0.9556
#
#  Start epoch 38
# discriminator loss at step 0: 0.5903
# generator loss at step 0: 1.0691
# discriminator loss at step 200: 0.6183
# generator loss at step 200: 0.8028
# discriminator loss at step 400: 0.6431
# generator loss at step 400: 0.9522
# discriminator loss at step 600: 0.6040
# generator loss at step 600: 0.9004
# discriminator loss at step 800: 0.6093
# generator loss at step 800: 0.9744
# discriminator loss at step 1000: 0.6326
# generator loss at step 1000: 1.0368
#
#  Start epoch 39
# discriminator loss at step 0: 0.6260
# generator loss at step 0: 1.3133
# discriminator loss at step 200: 0.5880
# generator loss at step 200: 0.9138
# discriminator loss at step 400: 0.6002
# generator loss at step 400: 0.8278
# discriminator loss at step 600: 0.6249
# generator loss at step 600: 0.9391
# discriminator loss at step 800: 0.6406
# generator loss at step 800: 0.9682
# discriminator loss at step 1000: 0.6732
# generator loss at step 1000: 0.8501
#
#  Start epoch 40
# discriminator loss at step 0: 0.6652
# generator loss at step 0: 1.1312
# discriminator loss at step 200: 0.6776
# generator loss at step 200: 0.8304
# discriminator loss at step 400: 0.6474
# generator loss at step 400: 1.0375
# discriminator loss at step 600: 0.6488
# generator loss at step 600: 0.9043
# discriminator loss at step 800: 0.6619
# generator loss at step 800: 1.0412
# discriminator loss at step 1000: 0.6344
# generator loss at step 1000: 0.9709
#
#  Start epoch 41
# discriminator loss at step 0: 0.6684
# generator loss at step 0: 1.0624
# discriminator loss at step 200: 0.6248
# generator loss at step 200: 0.9654
# discriminator loss at step 400: 0.6354
# generator loss at step 400: 0.8911
# discriminator loss at step 600: 0.6666
# generator loss at step 600: 0.8217
# discriminator loss at step 800: 0.6508
# generator loss at step 800: 0.9913
# discriminator loss at step 1000: 0.6606
# generator loss at step 1000: 1.0352
#
#  Start epoch 42
# discriminator loss at step 0: 0.6236
# generator loss at step 0: 1.1356
# discriminator loss at step 200: 0.6142
# generator loss at step 200: 0.9365
# discriminator loss at step 400: 0.6870
# generator loss at step 400: 1.0357
# discriminator loss at step 600: 0.6141
# generator loss at step 600: 0.7862
# discriminator loss at step 800: 0.6274
# generator loss at step 800: 0.9397
# discriminator loss at step 1000: 0.6312
# generator loss at step 1000: 0.8072
#
#  Start epoch 43
# discriminator loss at step 0: 0.6412
# generator loss at step 0: 1.2172
# discriminator loss at step 200: 0.6211
# generator loss at step 200: 0.9680
# discriminator loss at step 400: 0.6459
# generator loss at step 400: 0.8073
# discriminator loss at step 600: 0.6656
# generator loss at step 600: 0.8823
# discriminator loss at step 800: 0.6290
# generator loss at step 800: 0.9298
# discriminator loss at step 1000: 0.5810
# generator loss at step 1000: 0.9287
#
#  Start epoch 44
# discriminator loss at step 0: 0.6443
# generator loss at step 0: 1.1217
# discriminator loss at step 200: 0.6478
# generator loss at step 200: 0.9511
# discriminator loss at step 400: 0.5994
# generator loss at step 400: 0.9656
# discriminator loss at step 600: 0.6200
# generator loss at step 600: 0.8394
# discriminator loss at step 800: 0.6081
# generator loss at step 800: 1.0545
# discriminator loss at step 1000: 0.6481
# generator loss at step 1000: 1.0226
#
#  Start epoch 45
# discriminator loss at step 0: 0.6318
# generator loss at step 0: 1.2007
# discriminator loss at step 200: 0.6455
# generator loss at step 200: 0.8720
# discriminator loss at step 400: 0.6238
# generator loss at step 400: 0.9509
# discriminator loss at step 600: 0.6089
# generator loss at step 600: 0.8048
# discriminator loss at step 800: 0.6000
# generator loss at step 800: 0.9325
# discriminator loss at step 1000: 0.6129
# generator loss at step 1000: 1.0326
#
#  Start epoch 46
# discriminator loss at step 0: 0.6313
# generator loss at step 0: 0.9762
# discriminator loss at step 200: 0.6303
# generator loss at step 200: 0.8164
# discriminator loss at step 400: 0.6195
# generator loss at step 400: 0.9033
# discriminator loss at step 600: 0.6506
# generator loss at step 600: 1.0736
# discriminator loss at step 800: 0.5946
# generator loss at step 800: 1.0437
# discriminator loss at step 1000: 0.6463
# generator loss at step 1000: 0.8614
#
#  Start epoch 47
# discriminator loss at step 0: 0.6603
# generator loss at step 0: 1.0814
# discriminator loss at step 200: 0.6542
# generator loss at step 200: 0.8948
# discriminator loss at step 400: 0.6774
# generator loss at step 400: 0.8529
# discriminator loss at step 600: 0.7078
# generator loss at step 600: 0.8348
# discriminator loss at step 800: 0.6035
# generator loss at step 800: 1.0057
# discriminator loss at step 1000: 0.6296
# generator loss at step 1000: 0.9014
#
#  Start epoch 48
# discriminator loss at step 0: 0.6648
# generator loss at step 0: 1.1070
# discriminator loss at step 200: 0.6349
# generator loss at step 200: 0.8251
# discriminator loss at step 400: 0.6252
# generator loss at step 400: 1.0301
# discriminator loss at step 600: 0.6475
# generator loss at step 600: 1.2286
# discriminator loss at step 800: 0.6302
# generator loss at step 800: 0.9791
# discriminator loss at step 1000: 0.6325
# generator loss at step 1000: 0.9472
#
#  Start epoch 49
# discriminator loss at step 0: 0.6133
# generator loss at step 0: 1.0650
# discriminator loss at step 200: 0.6306
# generator loss at step 200: 0.9955
# discriminator loss at step 400: 0.6403
# generator loss at step 400: 0.9504
# discriminator loss at step 600: 0.6567
# generator loss at step 600: 0.7871
# discriminator loss at step 800: 0.6374
# generator loss at step 800: 0.8785
# discriminator loss at step 1000: 0.6451
# generator loss at step 1000: 0.9563
#
#  Start epoch 50
# discriminator loss at step 0: 0.6825
# generator loss at step 0: 1.1929
# discriminator loss at step 200: 0.6120
# generator loss at step 200: 1.0838
# discriminator loss at step 400: 0.6097
# generator loss at step 400: 0.9580
# discriminator loss at step 600: 0.6279
# generator loss at step 600: 1.0006
# discriminator loss at step 800: 0.5894
# generator loss at step 800: 0.9885
# discriminator loss at step 1000: 0.6371
# generator loss at step 1000: 1.0042
#
#  Start epoch 51
# discriminator loss at step 0: 0.5999
# generator loss at step 0: 1.3061
# discriminator loss at step 200: 0.6368
# generator loss at step 200: 0.8337
# discriminator loss at step 400: 0.6463
# generator loss at step 400: 0.8313
# discriminator loss at step 600: 0.6958
# generator loss at step 600: 0.9190
# discriminator loss at step 800: 0.6539
# generator loss at step 800: 1.0210
# discriminator loss at step 1000: 0.6371
# generator loss at step 1000: 0.8884
#
#  Start epoch 52
# discriminator loss at step 0: 0.5545
# generator loss at step 0: 1.0856
# discriminator loss at step 200: 0.6489
# generator loss at step 200: 0.8452
# discriminator loss at step 400: 0.6840
# generator loss at step 400: 0.9709
# discriminator loss at step 600: 0.6320
# generator loss at step 600: 0.9234
# discriminator loss at step 800: 0.6210
# generator loss at step 800: 1.0542
# discriminator loss at step 1000: 0.6549
# generator loss at step 1000: 0.9993
#
#  Start epoch 53
# discriminator loss at step 0: 0.6137
# generator loss at step 0: 1.1780
# discriminator loss at step 200: 0.6458
# generator loss at step 200: 0.8796
# discriminator loss at step 400: 0.6068
# generator loss at step 400: 0.8819
# discriminator loss at step 600: 0.6945
# generator loss at step 600: 0.8191
# discriminator loss at step 800: 0.6397
# generator loss at step 800: 0.9768
# discriminator loss at step 1000: 0.5992
# generator loss at step 1000: 0.7734
#
#  Start epoch 54
# discriminator loss at step 0: 0.6073
# generator loss at step 0: 1.2017
# discriminator loss at step 200: 0.6484
# generator loss at step 200: 0.8733
# discriminator loss at step 400: 0.6274
# generator loss at step 400: 0.8621
# discriminator loss at step 600: 0.6673
# generator loss at step 600: 0.9369
# discriminator loss at step 800: 0.6296
# generator loss at step 800: 1.0559
# discriminator loss at step 1000: 0.6282
# generator loss at step 1000: 0.8285
#
#  Start epoch 55
# discriminator loss at step 0: 0.6371
# generator loss at step 0: 1.1773
# discriminator loss at step 200: 0.6547
# generator loss at step 200: 0.7792
# discriminator loss at step 400: 0.6431
# generator loss at step 400: 0.8569
# discriminator loss at step 600: 0.6247
# generator loss at step 600: 0.8253
# discriminator loss at step 800: 0.6307
# generator loss at step 800: 0.8756
# discriminator loss at step 1000: 0.5619
# generator loss at step 1000: 0.9882
#
#  Start epoch 56
# discriminator loss at step 0: 0.6404
# generator loss at step 0: 1.1469
# discriminator loss at step 200: 0.6064
# generator loss at step 200: 1.0477
# discriminator loss at step 400: 0.6094
# generator loss at step 400: 0.8594
# discriminator loss at step 600: 0.6029
# generator loss at step 600: 0.8509
# discriminator loss at step 800: 0.6356
# generator loss at step 800: 0.8168
# discriminator loss at step 1000: 0.6422
# generator loss at step 1000: 1.0331
#
#  Start epoch 57
# discriminator loss at step 0: 0.5577
# generator loss at step 0: 1.0921
# discriminator loss at step 200: 0.6305
# generator loss at step 200: 0.9570
# discriminator loss at step 400: 0.6773
# generator loss at step 400: 0.7924
# discriminator loss at step 600: 0.6129
# generator loss at step 600: 0.8130
# discriminator loss at step 800: 0.6134
# generator loss at step 800: 1.0724
# discriminator loss at step 1000: 0.6517
# generator loss at step 1000: 1.0096
#
#  Start epoch 58
# discriminator loss at step 0: 0.6224
# generator loss at step 0: 0.9610
# discriminator loss at step 200: 0.6923
# generator loss at step 200: 0.9444
# discriminator loss at step 400: 0.6682
# generator loss at step 400: 0.9832
# discriminator loss at step 600: 0.6377
# generator loss at step 600: 1.0045
# discriminator loss at step 800: 0.5997
# generator loss at step 800: 0.8401
# discriminator loss at step 1000: 0.5936
# generator loss at step 1000: 1.0113
#
#  Start epoch 59
# discriminator loss at step 0: 0.5696
# generator loss at step 0: 1.0843
# discriminator loss at step 200: 0.6496
# generator loss at step 200: 0.8928
# discriminator loss at step 400: 0.5834
# generator loss at step 400: 0.9595
# discriminator loss at step 600: 0.6878
# generator loss at step 600: 0.9100
# discriminator loss at step 800: 0.5933
# generator loss at step 800: 0.9555
# discriminator loss at step 1000: 0.6291
# generator loss at step 1000: 0.8684
#
#  Start epoch 60
# discriminator loss at step 0: 0.6414
# generator loss at step 0: 1.1292
# discriminator loss at step 200: 0.6352
# generator loss at step 200: 1.0018
# discriminator loss at step 400: 0.6430
# generator loss at step 400: 0.9696
# discriminator loss at step 600: 0.6395
# generator loss at step 600: 0.9078
# discriminator loss at step 800: 0.5982
# generator loss at step 800: 0.9591
# discriminator loss at step 1000: 0.6269
# generator loss at step 1000: 0.9056
#
#  Start epoch 61
# discriminator loss at step 0: 0.6309
# generator loss at step 0: 1.1759
# discriminator loss at step 200: 0.6453
# generator loss at step 200: 0.8941
# discriminator loss at step 400: 0.6665
# generator loss at step 400: 0.8986
# discriminator loss at step 600: 0.6323
# generator loss at step 600: 1.0402
# discriminator loss at step 800: 0.5943
# generator loss at step 800: 0.9207
# discriminator loss at step 1000: 0.6370
# generator loss at step 1000: 1.0202
#
#  Start epoch 62
# discriminator loss at step 0: 0.6263
# generator loss at step 0: 1.0501
# discriminator loss at step 200: 0.6406
# generator loss at step 200: 0.9645
# discriminator loss at step 400: 0.5699
# generator loss at step 400: 0.8933
# discriminator loss at step 600: 0.6223
# generator loss at step 600: 1.0063
# discriminator loss at step 800: 0.6139
# generator loss at step 800: 0.9233
# discriminator loss at step 1000: 0.6156
# generator loss at step 1000: 0.9918
#
#  Start epoch 63
# discriminator loss at step 0: 0.5694
# generator loss at step 0: 1.0457
# discriminator loss at step 200: 0.7049
# generator loss at step 200: 1.0892
# discriminator loss at step 400: 0.6521
# generator loss at step 400: 0.9311
# discriminator loss at step 600: 0.6103
# generator loss at step 600: 0.8690
# discriminator loss at step 800: 0.5856
# generator loss at step 800: 0.9507
# discriminator loss at step 1000: 0.6179
# generator loss at step 1000: 0.8860
#
#  Start epoch 64
# discriminator loss at step 0: 0.6240
# generator loss at step 0: 0.9966
# discriminator loss at step 200: 0.6393
# generator loss at step 200: 0.8603
# discriminator loss at step 400: 0.6007
# generator loss at step 400: 1.1743
# discriminator loss at step 600: 0.6580
# generator loss at step 600: 0.7979
# discriminator loss at step 800: 0.6092
# generator loss at step 800: 0.8425
# discriminator loss at step 1000: 0.6020
# generator loss at step 1000: 1.0503
#
#  Start epoch 65
# discriminator loss at step 0: 0.6196
# generator loss at step 0: 1.2321
# discriminator loss at step 200: 0.6243
# generator loss at step 200: 0.9049
# discriminator loss at step 400: 0.6336
# generator loss at step 400: 0.8570
# discriminator loss at step 600: 0.6577
# generator loss at step 600: 0.9116
# discriminator loss at step 800: 0.5381
# generator loss at step 800: 1.1243
# discriminator loss at step 1000: 0.5946
# generator loss at step 1000: 0.8712
#
#  Start epoch 66
# discriminator loss at step 0: 0.6546
# generator loss at step 0: 1.1553
# discriminator loss at step 200: 0.6452
# generator loss at step 200: 1.0039
# discriminator loss at step 400: 0.6575
# generator loss at step 400: 1.0499
# discriminator loss at step 600: 0.6199
# generator loss at step 600: 0.9391
# discriminator loss at step 800: 0.6868
# generator loss at step 800: 0.9320
# discriminator loss at step 1000: 0.6062
# generator loss at step 1000: 0.9553
#
#  Start epoch 67
# discriminator loss at step 0: 0.6388
# generator loss at step 0: 1.1878
# discriminator loss at step 200: 0.6225
# generator loss at step 200: 1.0226
# discriminator loss at step 400: 0.6282
# generator loss at step 400: 0.8752
# discriminator loss at step 600: 0.6346
# generator loss at step 600: 0.9552
# discriminator loss at step 800: 0.6433
# generator loss at step 800: 0.8950
# discriminator loss at step 1000: 0.6440
# generator loss at step 1000: 0.9305
#
#  Start epoch 68
# discriminator loss at step 0: 0.5574
# generator loss at step 0: 1.0706
# discriminator loss at step 200: 0.6407
# generator loss at step 200: 0.9783
# discriminator loss at step 400: 0.6322
# generator loss at step 400: 0.9407
# discriminator loss at step 600: 0.6355
# generator loss at step 600: 0.9485
# discriminator loss at step 800: 0.5977
# generator loss at step 800: 1.1241
# discriminator loss at step 1000: 0.6057
# generator loss at step 1000: 0.9978
#
#  Start epoch 69
# discriminator loss at step 0: 0.6262
# generator loss at step 0: 1.1938
# discriminator loss at step 200: 0.6649
# generator loss at step 200: 0.9801
# discriminator loss at step 400: 0.6058
# generator loss at step 400: 0.9336
# discriminator loss at step 600: 0.5879
# generator loss at step 600: 0.7996
# discriminator loss at step 800: 0.6400
# generator loss at step 800: 1.0100
# discriminator loss at step 1000: 0.6422
# generator loss at step 1000: 1.0457
#
#  Start epoch 70
# discriminator loss at step 0: 0.5596
# generator loss at step 0: 1.2093
# discriminator loss at step 200: 0.6321
# generator loss at step 200: 0.9568
# discriminator loss at step 400: 0.5678
# generator loss at step 400: 0.9775
# discriminator loss at step 600: 0.6511
# generator loss at step 600: 0.9808
# discriminator loss at step 800: 0.5751
# generator loss at step 800: 0.9430
# discriminator loss at step 1000: 0.5931
# generator loss at step 1000: 0.8963
#
#  Start epoch 71
# discriminator loss at step 0: 0.6296
# generator loss at step 0: 1.0534
# discriminator loss at step 200: 0.6072
# generator loss at step 200: 0.8646
# discriminator loss at step 400: 0.6150
# generator loss at step 400: 0.8771
# discriminator loss at step 600: 0.6304
# generator loss at step 600: 0.9360
# discriminator loss at step 800: 0.6011
# generator loss at step 800: 0.9315
# discriminator loss at step 1000: 0.6680
# generator loss at step 1000: 0.9151
#
#  Start epoch 72
# discriminator loss at step 0: 0.5848
# generator loss at step 0: 1.1335
# discriminator loss at step 200: 0.6669
# generator loss at step 200: 0.9708
# discriminator loss at step 400: 0.6176
# generator loss at step 400: 0.9543
# discriminator loss at step 600: 0.6323
# generator loss at step 600: 0.9812
# discriminator loss at step 800: 0.6545
# generator loss at step 800: 1.0186
# discriminator loss at step 1000: 0.5747
# generator loss at step 1000: 0.9100
#
#  Start epoch 73
# discriminator loss at step 0: 0.6438
# generator loss at step 0: 1.3895
# discriminator loss at step 200: 0.6685
# generator loss at step 200: 0.8926
# discriminator loss at step 400: 0.6185
# generator loss at step 400: 0.9674
# discriminator loss at step 600: 0.6630
# generator loss at step 600: 1.1033
# discriminator loss at step 800: 0.6114
# generator loss at step 800: 0.9261
# discriminator loss at step 1000: 0.6193
# generator loss at step 1000: 0.8280
#
#  Start epoch 74
# discriminator loss at step 0: 0.6512
# generator loss at step 0: 1.1201
# discriminator loss at step 200: 0.6480
# generator loss at step 200: 0.9777
# discriminator loss at step 400: 0.6810
# generator loss at step 400: 0.9789
# discriminator loss at step 600: 0.6464
# generator loss at step 600: 0.9946
# discriminator loss at step 800: 0.6014
# generator loss at step 800: 0.8727
# discriminator loss at step 1000: 0.6024
# generator loss at step 1000: 0.9944
#
#  Start epoch 75
# discriminator loss at step 0: 0.5704
# generator loss at step 0: 1.1859
# discriminator loss at step 200: 0.6092
# generator loss at step 200: 0.9386
# discriminator loss at step 400: 0.6187
# generator loss at step 400: 0.9376
# discriminator loss at step 600: 0.6471
# generator loss at step 600: 1.0260
# discriminator loss at step 800: 0.6164
# generator loss at step 800: 0.8476
# discriminator loss at step 1000: 0.6250
# generator loss at step 1000: 1.1527
#
#  Start epoch 76
# discriminator loss at step 0: 0.5881
# generator loss at step 0: 1.2346
# discriminator loss at step 200: 0.5914
# generator loss at step 200: 1.0658
# discriminator loss at step 400: 0.6806
# generator loss at step 400: 1.0524
# discriminator loss at step 600: 0.6510
# generator loss at step 600: 1.0515
# discriminator loss at step 800: 0.6596
# generator loss at step 800: 1.0042
# discriminator loss at step 1000: 0.6119
# generator loss at step 1000: 0.8803
#
#  Start epoch 77
# discriminator loss at step 0: 0.6377
# generator loss at step 0: 1.2246
# discriminator loss at step 200: 0.6048
# generator loss at step 200: 0.8156
# discriminator loss at step 400: 0.6234
# generator loss at step 400: 0.9435
# discriminator loss at step 600: 0.5900
# generator loss at step 600: 0.9273
# discriminator loss at step 800: 0.6287
# generator loss at step 800: 0.7589
# discriminator loss at step 1000: 0.6235
# generator loss at step 1000: 1.0292
#
#  Start epoch 78
# discriminator loss at step 0: 0.5827
# generator loss at step 0: 1.3998
# discriminator loss at step 200: 0.5776
# generator loss at step 200: 1.0223
# discriminator loss at step 400: 0.6202
# generator loss at step 400: 0.9528
# discriminator loss at step 600: 0.6212
# generator loss at step 600: 0.9455
# discriminator loss at step 800: 0.5986
# generator loss at step 800: 0.8513
# discriminator loss at step 1000: 0.5957
# generator loss at step 1000: 1.0157
#
#  Start epoch 79
# discriminator loss at step 0: 0.5928
# generator loss at step 0: 1.1578
# discriminator loss at step 200: 0.6463
# generator loss at step 200: 1.1241
# discriminator loss at step 400: 0.5682
# generator loss at step 400: 1.0604
# discriminator loss at step 600: 0.6257
# generator loss at step 600: 0.9511
# discriminator loss at step 800: 0.5881
# generator loss at step 800: 0.9218
# discriminator loss at step 1000: 0.6445
# generator loss at step 1000: 0.9230
#
#  Start epoch 80
# discriminator loss at step 0: 0.5914
# generator loss at step 0: 1.2179
# discriminator loss at step 200: 0.6434
# generator loss at step 200: 0.8926
# discriminator loss at step 400: 0.6049
# generator loss at step 400: 1.0210
# discriminator loss at step 600: 0.6314
# generator loss at step 600: 0.8344
# discriminator loss at step 800: 0.6428
# generator loss at step 800: 0.9488
# discriminator loss at step 1000: 0.6072
# generator loss at step 1000: 1.1358
#
#  Start epoch 81
# discriminator loss at step 0: 0.6781
# generator loss at step 0: 1.0553
# discriminator loss at step 200: 0.6507
# generator loss at step 200: 0.9564
# discriminator loss at step 400: 0.5731
# generator loss at step 400: 1.0051
# discriminator loss at step 600: 0.6600
# generator loss at step 600: 0.8201
# discriminator loss at step 800: 0.5754
# generator loss at step 800: 0.9998
# discriminator loss at step 1000: 0.6539
# generator loss at step 1000: 0.8934
#
#  Start epoch 82
# discriminator loss at step 0: 0.6215
# generator loss at step 0: 1.1971
# discriminator loss at step 200: 0.6443
# generator loss at step 200: 1.0828
# discriminator loss at step 400: 0.6023
# generator loss at step 400: 1.0029
# discriminator loss at step 600: 0.6045
# generator loss at step 600: 0.9752
# discriminator loss at step 800: 0.6457
# generator loss at step 800: 1.0486
# discriminator loss at step 1000: 0.6175
# generator loss at step 1000: 0.9875
#
#  Start epoch 83
# discriminator loss at step 0: 0.5868
# generator loss at step 0: 1.0035
# discriminator loss at step 200: 0.6465
# generator loss at step 200: 1.0082
# discriminator loss at step 400: 0.6209
# generator loss at step 400: 0.9859
# discriminator loss at step 600: 0.6372
# generator loss at step 600: 0.8900
# discriminator loss at step 800: 0.6202
# generator loss at step 800: 1.0533
# discriminator loss at step 1000: 0.6184
# generator loss at step 1000: 1.0014
#
#  Start epoch 84
# discriminator loss at step 0: 0.6395
# generator loss at step 0: 0.9898
# discriminator loss at step 200: 0.6411
# generator loss at step 200: 0.9639
# discriminator loss at step 400: 0.6316
# generator loss at step 400: 0.8679
# discriminator loss at step 600: 0.6330
# generator loss at step 600: 1.1025
# discriminator loss at step 800: 0.6567
# generator loss at step 800: 0.9913
# discriminator loss at step 1000: 0.6950
# generator loss at step 1000: 0.8942
#
#  Start epoch 85
# discriminator loss at step 0: 0.5989
# generator loss at step 0: 1.0534
# discriminator loss at step 200: 0.6391
# generator loss at step 200: 0.8046
# discriminator loss at step 400: 0.6604
# generator loss at step 400: 1.1430
# discriminator loss at step 600: 0.6655
# generator loss at step 600: 0.8812
# discriminator loss at step 800: 0.6196
# generator loss at step 800: 0.9576
# discriminator loss at step 1000: 0.5986
# generator loss at step 1000: 1.0544
#
#  Start epoch 86
# discriminator loss at step 0: 0.5980
# generator loss at step 0: 1.1548
# discriminator loss at step 200: 0.6805
# generator loss at step 200: 0.9345
# discriminator loss at step 400: 0.6212
# generator loss at step 400: 1.0636
# discriminator loss at step 600: 0.6266
# generator loss at step 600: 1.0735
# discriminator loss at step 800: 0.6493
# generator loss at step 800: 0.9505
# discriminator loss at step 1000: 0.6678
# generator loss at step 1000: 1.0456
#
#  Start epoch 87
# discriminator loss at step 0: 0.6059
# generator loss at step 0: 1.1721
# discriminator loss at step 200: 0.5967
# generator loss at step 200: 0.9743
# discriminator loss at step 400: 0.5960
# generator loss at step 400: 1.1073
# discriminator loss at step 600: 0.6314
# generator loss at step 600: 1.0197
# discriminator loss at step 800: 0.6345
# generator loss at step 800: 1.0367
# discriminator loss at step 1000: 0.6232
# generator loss at step 1000: 0.8563
#
#  Start epoch 88
# discriminator loss at step 0: 0.5838
# generator loss at step 0: 1.0286
# discriminator loss at step 200: 0.5912
# generator loss at step 200: 0.8730
# discriminator loss at step 400: 0.6555
# generator loss at step 400: 0.9087
# discriminator loss at step 600: 0.6492
# generator loss at step 600: 0.9529
# discriminator loss at step 800: 0.6354
# generator loss at step 800: 1.0430
# discriminator loss at step 1000: 0.6346
# generator loss at step 1000: 1.0205
#
#  Start epoch 89
# discriminator loss at step 0: 0.5966
# generator loss at step 0: 1.4011
# discriminator loss at step 200: 0.6122
# generator loss at step 200: 0.9310
# discriminator loss at step 400: 0.6545
# generator loss at step 400: 0.7933
# discriminator loss at step 600: 0.6542
# generator loss at step 600: 1.0626
# discriminator loss at step 800: 0.6105
# generator loss at step 800: 0.8889
# discriminator loss at step 1000: 0.6249
# generator loss at step 1000: 0.9722
#
#  Start epoch 90
# discriminator loss at step 0: 0.6480
# generator loss at step 0: 1.0909
# discriminator loss at step 200: 0.6498
# generator loss at step 200: 0.9870
# discriminator loss at step 400: 0.6541
# generator loss at step 400: 0.7353
# discriminator loss at step 600: 0.5947
# generator loss at step 600: 1.1479
# discriminator loss at step 800: 0.6538
# generator loss at step 800: 1.3087
# discriminator loss at step 1000: 0.5880
# generator loss at step 1000: 0.9784
#
#  Start epoch 91
# discriminator loss at step 0: 0.5746
# generator loss at step 0: 1.3018
# discriminator loss at step 200: 0.5963
# generator loss at step 200: 0.8837
# discriminator loss at step 400: 0.6296
# generator loss at step 400: 0.8724
# discriminator loss at step 600: 0.5721
# generator loss at step 600: 0.8777
# discriminator loss at step 800: 0.5879
# generator loss at step 800: 0.8963
# discriminator loss at step 1000: 0.5842
# generator loss at step 1000: 0.9124
#
#  Start epoch 92
# discriminator loss at step 0: 0.6241
# generator loss at step 0: 1.2765
# discriminator loss at step 200: 0.6325
# generator loss at step 200: 0.9403
# discriminator loss at step 400: 0.6359
# generator loss at step 400: 0.9203
# discriminator loss at step 600: 0.5782
# generator loss at step 600: 1.0036
# discriminator loss at step 800: 0.6198
# generator loss at step 800: 1.1516
# discriminator loss at step 1000: 0.6281
# generator loss at step 1000: 1.0950
#
#  Start epoch 93
# discriminator loss at step 0: 0.6523
# generator loss at step 0: 1.1713
# discriminator loss at step 200: 0.6330
# generator loss at step 200: 0.8367
# discriminator loss at step 400: 0.5641
# generator loss at step 400: 0.9850
# discriminator loss at step 600: 0.6676
# generator loss at step 600: 0.7692
# discriminator loss at step 800: 0.6204
# generator loss at step 800: 0.9980
# discriminator loss at step 1000: 0.5961
# generator loss at step 1000: 1.0242
#
#  Start epoch 94
# discriminator loss at step 0: 0.5741
# generator loss at step 0: 1.1826
# discriminator loss at step 200: 0.6547
# generator loss at step 200: 0.8125
# discriminator loss at step 400: 0.6177
# generator loss at step 400: 1.0974
# discriminator loss at step 600: 0.6461
# generator loss at step 600: 1.0032
# discriminator loss at step 800: 0.6622
# generator loss at step 800: 0.8607
# discriminator loss at step 1000: 0.5899
# generator loss at step 1000: 1.0088
#
#  Start epoch 95
# discriminator loss at step 0: 0.5678
# generator loss at step 0: 1.0891
# discriminator loss at step 200: 0.6281
# generator loss at step 200: 0.7971
# discriminator loss at step 400: 0.6048
# generator loss at step 400: 0.8948
# discriminator loss at step 600: 0.5739
# generator loss at step 600: 0.9139
# discriminator loss at step 800: 0.6062
# generator loss at step 800: 0.9282
# discriminator loss at step 1000: 0.6070
# generator loss at step 1000: 0.9744
#
#  Start epoch 96
# discriminator loss at step 0: 0.6074
# generator loss at step 0: 0.9180
# discriminator loss at step 200: 0.6441
# generator loss at step 200: 0.9794
# discriminator loss at step 400: 0.6155
# generator loss at step 400: 1.0469
# discriminator loss at step 600: 0.6089
# generator loss at step 600: 1.0058
# discriminator loss at step 800: 0.6422
# generator loss at step 800: 0.9361
# discriminator loss at step 1000: 0.6312
# generator loss at step 1000: 1.1024
#
#  Start epoch 97
# discriminator loss at step 0: 0.5779
# generator loss at step 0: 1.1460
# discriminator loss at step 200: 0.6209
# generator loss at step 200: 0.9044
# discriminator loss at step 400: 0.5912
# generator loss at step 400: 0.9787
# discriminator loss at step 600: 0.6348
# generator loss at step 600: 0.7494
# discriminator loss at step 800: 0.5992
# generator loss at step 800: 1.0718
# discriminator loss at step 1000: 0.5694
# generator loss at step 1000: 1.2323
#
#  Start epoch 98
# discriminator loss at step 0: 0.6045
# generator loss at step 0: 1.3098
# discriminator loss at step 200: 0.6211
# generator loss at step 200: 0.7918
# discriminator loss at step 400: 0.5804
# generator loss at step 400: 0.8861
# discriminator loss at step 600: 0.6407
# generator loss at step 600: 1.0240
# discriminator loss at step 800: 0.6540
# generator loss at step 800: 0.8575
# discriminator loss at step 1000: 0.6101
# generator loss at step 1000: 0.9626
#
#  Start epoch 99
# discriminator loss at step 0: 0.6193
# generator loss at step 0: 1.0962
# discriminator loss at step 200: 0.6388
# generator loss at step 200: 0.8593
# discriminator loss at step 400: 0.6217
# generator loss at step 400: 1.1044
# discriminator loss at step 600: 0.6140
# generator loss at step 600: 0.9136
# discriminator loss at step 800: 0.6122
# generator loss at step 800: 1.0239
# discriminator loss at step 1000: 0.6129
# generator loss at step 1000: 0.9306
